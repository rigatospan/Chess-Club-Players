# %%
# fetch the original table from web-scrapping
import pandas as pd
import numpy as np
from datetime import datetime

# import and inspect the table
df_eso_fide_players = pd.read_csv('..\\eso_and_fide_players_ratings.csv')
df_eso_fide_players.head()
# Out:
#    ΑΑ  ΚΩΔΙΚΟΣ       FIDE                                ΟΝΟΜΑ      Η/Γ ΦΥΛΟ  \
# 0   1    36055        NaN       ΜΑΪΕΡ ΧΑΝΣ - ΚΡΙΣΤΙΑΝ - ΜΙΧΑΕΛ  01/1959    Α
# 1   2    30932  4232984.0  ΔΡΑΚΟΠΟΥΛΟΣ ΠΟΛΥΧΡΟΝΗΣ - ΠΑΝΑΓΙΩΤΗΣ  05/1998    Α
# 2   3    29392  4231813.0              ΤΣΑΓΚΑΡΟΠΟΥΛΟΣ ΣΠΥΡΙΔΩΝ  02/1989    Α
# 3   4     9345  4204123.0                ΣΠΥΡΑΚΟΠΟΥΛΟΣ ΙΩΑΝΝΗΣ  12/1971    Α
# 4   5    25836  4211421.0                     ΛΙΑΣΚΟΣ ΛΕΩΝΙΔΑΣ  03/1993    Α
#
#   ΤΙΤΛΟΣ   ΕΛΟ  ΠΑΡΤΙΔΕΣ    *  ...  \
# 0    NaN  2336       0.0  NaN  ...
# 1    NaN  1961       2.0  NaN  ...
# 2     ΒΚ  1949       2.0  NaN  ...
# 3     ΟΜ  1947       0.0  NaN  ...
# 4     ΑΚ  1929       2.0  NaN  ...
#
#                                           fide link eso player history  \
# 0         http://ratings.fide.com/card.phtml?event=  /eso/player/36055
# 1  http://ratings.fide.com/card.phtml?event=4232984  /eso/player/30932
# 2  http://ratings.fide.com/card.phtml?event=4231813  /eso/player/29392
# 3  http://ratings.fide.com/card.phtml?event=4204123  /eso/player/09345
# 4  http://ratings.fide.com/card.phtml?event=4211421  /eso/player/25836
#
#   eso player last 6 month games                fide name   std rapid blitz  \
# 0                           NaN                      NaN   NaN   NaN   NaN
# 1        /eso/playergames/30932   Drakopoulos Polihronis  2114  2037  1977
# 2        /eso/playergames/29392  Tsagkaropoulos Spyridon  2068  1999  1991
# 3                           NaN    Spirakopoulos Ioannis  2035  1998  2009
# 4        /eso/playergames/25836         Liaskos Leonidas  2007  2011  2087
#
#   federation National Rank All  National Rank Active
# 0        NaN               NaN                   NaN
# 1        GRE             305.0                 178.0
# 2        GRE             410.0                 226.0
# 3        GRE             488.0                 263.0
# 4        GRE             574.0                 299.0
#
# [5 rows x 21 columns]

# %%
print(df_eso_fide_players.columns)
# Out:
# Index(['ΑΑ', 'ΚΩΔΙΚΟΣ', 'FIDE', 'ΟΝΟΜΑ', 'Η/Γ', 'ΦΥΛΟ', 'ΤΙΤΛΟΣ', 'ΕΛΟ',
#        'ΠΑΡΤΙΔΕΣ', '*', 'ΤΔ', 'fide link', 'eso player history',
#        'eso player last 6 month games', 'fide name', 'std', 'rapid', 'blitz',
#        'federation', 'National Rank All', 'National Rank Active'],
#       dtype='object')

# %% [markdown]
# ## Reforming and Renaming the table

# %%
# replace NaN values and othe empty values: 'Not rated', '-' with '0'
modified_players_list = df_eso_fide_players.fillna('0').replace(['Not rated', '-'], '0')

# replace gender Greek characters to English
modified_players_list = modified_players_list.replace(['Α','Θ'], ['M','F'])

# create a column with the Fide Id hyperlinked when using .style attribute
def make_clickable(url, value_to_apply_url):
    return '<a href="{}">{}</a>'.format(url,value_to_apply_url)

modified_players_list['FIDE'] = modified_players_list['FIDE'].astype(int)
modified_players_list['Fide ID'] = modified_players_list.apply(lambda col: make_clickable(col['fide link'], col['FIDE']) , axis=1)

# discard hyperlink columns
modified_players_list = pd.concat([modified_players_list.iloc[:, :11] , modified_players_list.iloc[:, 14:]], axis=1)


# transform integer values to int type
for col in modified_players_list.columns:
    try:
        modified_players_list[col] = modified_players_list[col].astype(int)
    except:
        pass

# renaming column index 
modified_players_list = modified_players_list.rename(columns= {
                            'ΑΑ': 'Club Rank National',
                            'ΚΩΔΙΚΟΣ': 'National ID',
                            'FIDE': 'Fide',
                            'ΟΝΟΜΑ': 'National Name',
                            'Η/Γ': 'Date of Birth' ,
                            'ΦΥΛΟ': 'Gender',
                            'ΤΙΤΛΟΣ': "National Title",
                            'ΕΛΟ': 'National Elo',
                            'ΠΑΡΤΙΔΕΣ': 'Games last 6 months',
                            '*': 'Outsider' ,
                            'ΤΔ': 'Eso Fee',
                            'fide name' : 'Fide Name',
                            'federation' : 'Federation',
                            })

# parse the date of birth and creare a new Age column 
modified_players_list['Birthday'] = pd.to_datetime('01/'+ modified_players_list['Date of Birth'], dayfirst=True)
modified_players_list['Age'] = modified_players_list['Birthday'].map(lambda x: datetime.today().year - x.year)

# create a column with boolean values to state if the player appears active in fide or not
modified_players_list['Fide Active'] = modified_players_list['National Rank Active'].map( lambda rank_active: rank_active > 0)

col_toshow = [
        'National Name',
        'Fide Name',
        'National Elo', 
        'std', 
        'rapid', 
        'blitz',
        'Age',
        'Birthday',
        'Eso Fee', 
        'Fide Active', 
        'Gender',
        'National ID',
        'Fide ID',
        'Federation',
        'National Title',
        ]
table_toshow = pd.concat([modified_players_list[col] for col in col_toshow], axis=1)
table_toshow.head()
# Out:
#                          National Name                Fide Name  National Elo  \
# 0       ΜΑΪΕΡ ΧΑΝΣ - ΚΡΙΣΤΙΑΝ - ΜΙΧΑΕΛ                        0          2336
# 1  ΔΡΑΚΟΠΟΥΛΟΣ ΠΟΛΥΧΡΟΝΗΣ - ΠΑΝΑΓΙΩΤΗΣ   Drakopoulos Polihronis          1961
# 2              ΤΣΑΓΚΑΡΟΠΟΥΛΟΣ ΣΠΥΡΙΔΩΝ  Tsagkaropoulos Spyridon          1949
# 3                ΣΠΥΡΑΚΟΠΟΥΛΟΣ ΙΩΑΝΝΗΣ    Spirakopoulos Ioannis          1947
# 4                     ΛΙΑΣΚΟΣ ΛΕΩΝΙΔΑΣ         Liaskos Leonidas          1929
#
#     std  rapid  blitz  Age   Birthday Eso Fee  Fide Active Gender  \
# 0     0      0      0   65 1959-01-01       0        False      M
# 1  2114   2037   1977   26 1998-05-01      OK         True      M
# 2  2068   1999   1991   35 1989-02-01      OK         True      M
# 3  2035   1998   2009   53 1971-12-01      OK         True      M
# 4  2007   2011   2087   31 1993-03-01      OK         True      M
#
#    National ID                                            Fide ID Federation  \
# 0        36055  <a href="http://ratings.fide.com/card.phtml?ev...          0
# 1        30932  <a href="http://ratings.fide.com/card.phtml?ev...        GRE
# 2        29392  <a href="http://ratings.fide.com/card.phtml?ev...        GRE
# 3         9345  <a href="http://ratings.fide.com/card.phtml?ev...        GRE
# 4        25836  <a href="http://ratings.fide.com/card.phtml?ev...        GRE
#
#   National Title
# 0              0
# 1              0
# 2             ΒΚ
# 3             ΟΜ
# 4             ΑΚ

# %%
pd.to_datetime('01/' + modified_players_list['Date of Birth'], dayfirst=True)
# Out:
# 0     1959-01-01
# 1     1998-05-01
# 2     1989-02-01
# 3     1971-12-01
# 4     1993-03-01
#          ...
# 482   2002-03-01
# 483   2004-12-01
# 484   2012-08-01
# 485   2014-03-01
# 486   2016-03-01
# Name: Date of Birth, Length: 487, dtype: datetime64[ns]

# %% [markdown]
# ## apply restrictions to the table
#
# Restrictions could be the following:
# - Gender
# - Eso fee
# - sort by std or eso rating
# - active status
# - age

# %%
# table to present
col_toshow = [
       'National Name',
        'National Elo', 
        'std', 
        'rapid', 
        'blitz',
        'Age', 
        'Eso Fee', 
        'Fide Active Player', 
        'Gender',
        'National ID',
        'Fide ID hyperlink' 
        ]
table_toshow = pd.concat([modified_players_list[col] for col in col_toshow], axis=1)

table_toshow.to_pickle('table_toshow.pkl')

table_toshow.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff034">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff034_level0_col0" class="col_heading level0 col0" >National Name</th>
#       <th id="T_ff034_level0_col1" class="col_heading level0 col1" >National Elo</th>
#       <th id="T_ff034_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_ff034_level0_col3" class="col_heading level0 col3" >rapid</th>
#       <th id="T_ff034_level0_col4" class="col_heading level0 col4" >blitz</th>
#       <th id="T_ff034_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_ff034_level0_col6" class="col_heading level0 col6" >Eso Fee</th>
#       <th id="T_ff034_level0_col7" class="col_heading level0 col7" >Fide Active Player</th>
#       <th id="T_ff034_level0_col8" class="col_heading level0 col8" >Gender</th>
#       <th id="T_ff034_level0_col9" class="col_heading level0 col9" >National ID</th>
#       <th id="T_ff034_level0_col10" class="col_heading level0 col10" >Fide ID hyperlink</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff034_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff034_row0_col0" class="data row0 col0" >ΜΑΪΕΡ ΧΑΝΣ - ΚΡΙΣΤΙΑΝ - ΜΙΧΑΕΛ</td>
#       <td id="T_ff034_row0_col1" class="data row0 col1" >2336</td>
#       <td id="T_ff034_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_ff034_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ff034_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ff034_row0_col5" class="data row0 col5" >65</td>
#       <td id="T_ff034_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_ff034_row0_col7" class="data row0 col7" >False</td>
#       <td id="T_ff034_row0_col8" class="data row0 col8" >M</td>
#       <td id="T_ff034_row0_col9" class="data row0 col9" >36055</td>
#       <td id="T_ff034_row0_col10" class="data row0 col10" ><a href="http://ratings.fide.com/card.phtml?event=">0</a></td>
#     </tr>
#     <tr>
#       <th id="T_ff034_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff034_row1_col0" class="data row1 col0" >ΔΡΑΚΟΠΟΥΛΟΣ ΠΟΛΥΧΡΟΝΗΣ - ΠΑΝΑΓΙΩΤΗΣ</td>
#       <td id="T_ff034_row1_col1" class="data row1 col1" >1961</td>
#       <td id="T_ff034_row1_col2" class="data row1 col2" >2114</td>
#       <td id="T_ff034_row1_col3" class="data row1 col3" >2037</td>
#       <td id="T_ff034_row1_col4" class="data row1 col4" >1977</td>
#       <td id="T_ff034_row1_col5" class="data row1 col5" >26</td>
#       <td id="T_ff034_row1_col6" class="data row1 col6" >OK</td>
#       <td id="T_ff034_row1_col7" class="data row1 col7" >True</td>
#       <td id="T_ff034_row1_col8" class="data row1 col8" >M</td>
#       <td id="T_ff034_row1_col9" class="data row1 col9" >30932</td>
#       <td id="T_ff034_row1_col10" class="data row1 col10" ><a href="http://ratings.fide.com/card.phtml?event=4232984">4232984</a></td>
#     </tr>
#     <tr>
#       <th id="T_ff034_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff034_row2_col0" class="data row2 col0" >ΤΣΑΓΚΑΡΟΠΟΥΛΟΣ ΣΠΥΡΙΔΩΝ</td>
#       <td id="T_ff034_row2_col1" class="data row2 col1" >1949</td>
#       <td id="T_ff034_row2_col2" class="data row2 col2" >2068</td>
#       <td id="T_ff034_row2_col3" class="data row2 col3" >1999</td>
#       <td id="T_ff034_row2_col4" class="data row2 col4" >1991</td>
#       <td id="T_ff034_row2_col5" class="data row2 col5" >35</td>
#       <td id="T_ff034_row2_col6" class="data row2 col6" >OK</td>
#       <td id="T_ff034_row2_col7" class="data row2 col7" >True</td>
#       <td id="T_ff034_row2_col8" class="data row2 col8" >M</td>
#       <td id="T_ff034_row2_col9" class="data row2 col9" >29392</td>
#       <td id="T_ff034_row2_col10" class="data row2 col10" ><a href="http://ratings.fide.com/card.phtml?event=4231813">4231813</a></td>
#     </tr>
#     <tr>
#       <th id="T_ff034_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff034_row3_col0" class="data row3 col0" >ΣΠΥΡΑΚΟΠΟΥΛΟΣ ΙΩΑΝΝΗΣ</td>
#       <td id="T_ff034_row3_col1" class="data row3 col1" >1947</td>
#       <td id="T_ff034_row3_col2" class="data row3 col2" >2035</td>
#       <td id="T_ff034_row3_col3" class="data row3 col3" >1998</td>
#       <td id="T_ff034_row3_col4" class="data row3 col4" >2009</td>
#       <td id="T_ff034_row3_col5" class="data row3 col5" >53</td>
#       <td id="T_ff034_row3_col6" class="data row3 col6" >OK</td>
#       <td id="T_ff034_row3_col7" class="data row3 col7" >True</td>
#       <td id="T_ff034_row3_col8" class="data row3 col8" >M</td>
#       <td id="T_ff034_row3_col9" class="data row3 col9" >9345</td>
#       <td id="T_ff034_row3_col10" class="data row3 col10" ><a href="http://ratings.fide.com/card.phtml?event=4204123">4204123</a></td>
#     </tr>
#     <tr>
#       <th id="T_ff034_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff034_row4_col0" class="data row4 col0" >ΛΙΑΣΚΟΣ ΛΕΩΝΙΔΑΣ</td>
#       <td id="T_ff034_row4_col1" class="data row4 col1" >1929</td>
#       <td id="T_ff034_row4_col2" class="data row4 col2" >2007</td>
#       <td id="T_ff034_row4_col3" class="data row4 col3" >2011</td>
#       <td id="T_ff034_row4_col4" class="data row4 col4" >2087</td>
#       <td id="T_ff034_row4_col5" class="data row4 col5" >31</td>
#       <td id="T_ff034_row4_col6" class="data row4 col6" >OK</td>
#       <td id="T_ff034_row4_col7" class="data row4 col7" >True</td>
#       <td id="T_ff034_row4_col8" class="data row4 col8" >M</td>
#       <td id="T_ff034_row4_col9" class="data row4 col9" >25836</td>
#       <td id="T_ff034_row4_col10" class="data row4 col10" ><a href="http://ratings.fide.com/card.phtml?event=4211421">4211421</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
def restrictions(
                 table,
                 elo_type = 'std', 
                 elo_min = 0,
                 elo_max = float('inf'),
                 age_min = 0,
                 age_max = float('inf'),
                 gender = None, 
                 eso_fee = None, 
                 fide_active = None
                  ):

    restrictions = []
    
    if elo_min >0 or elo_max < float('inf'):
        elo_restriction = ( (table_toshow[elo_type] >= elo_min) & (table_toshow[elo_type] <= elo_max) )
        restrictions.append(elo_restriction)

    if age_min >0 or age_max < float('inf'):
        age_restriction = ( (table_toshow['Age']>=age_min ) & (table_toshow['Age'] <= age_max) )
        restrictions.append(age_restriction)
    
    if fide_active!= None and fide_active in [True, False]:
        fide_active_restriction =  table_toshow['Fide Active Player'] == fide_active
        restrictions.append(fide_active_restriction)

    if eso_fee != None and eso_fee in ['OK', '0']:
        eso_fee_restriction = table_toshow['Eso Fee'] == eso_fee
        restrictions.append(eso_fee_restriction)
    
    if gender!= None and gender in 'MF':
        gender_restriction = table_toshow['Gender'] == gender
        restrictions.append(gender_restriction)

    if len(restrictions) == 0:
        return table
    
    # continue if there are some restrictions to apply
    all_restrictions = restrictions[0]

    # combine all restrictions with the logical and operator &
    # I haven't found a way to do that by a built in function
    for res in restrictions:
        all_restrictions = all_restrictions & res    
    
    return table[all_restrictions].sort_values(by=['std','National Elo','Age','National ID'], ascending= False)

# %%
restrictions(
             table_toshow,   
             elo_min = 1100,
             age_max= 30,
            #  gender = None, 
            #  fide_active = True,
             eso_fee= None
             ).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad4d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad4d9_level0_col0" class="col_heading level0 col0" >National Name</th>
#       <th id="T_ad4d9_level0_col1" class="col_heading level0 col1" >National Elo</th>
#       <th id="T_ad4d9_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_ad4d9_level0_col3" class="col_heading level0 col3" >rapid</th>
#       <th id="T_ad4d9_level0_col4" class="col_heading level0 col4" >blitz</th>
#       <th id="T_ad4d9_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_ad4d9_level0_col6" class="col_heading level0 col6" >Eso Fee</th>
#       <th id="T_ad4d9_level0_col7" class="col_heading level0 col7" >Fide Active Player</th>
#       <th id="T_ad4d9_level0_col8" class="col_heading level0 col8" >Gender</th>
#       <th id="T_ad4d9_level0_col9" class="col_heading level0 col9" >National ID</th>
#       <th id="T_ad4d9_level0_col10" class="col_heading level0 col10" >Fide ID hyperlink</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad4d9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ad4d9_row0_col0" class="data row0 col0" >ΔΡΑΚΟΠΟΥΛΟΣ ΠΟΛΥΧΡΟΝΗΣ - ΠΑΝΑΓΙΩΤΗΣ</td>
#       <td id="T_ad4d9_row0_col1" class="data row0 col1" >1961</td>
#       <td id="T_ad4d9_row0_col2" class="data row0 col2" >2114</td>
#       <td id="T_ad4d9_row0_col3" class="data row0 col3" >2037</td>
#       <td id="T_ad4d9_row0_col4" class="data row0 col4" >1977</td>
#       <td id="T_ad4d9_row0_col5" class="data row0 col5" >26</td>
#       <td id="T_ad4d9_row0_col6" class="data row0 col6" >OK</td>
#       <td id="T_ad4d9_row0_col7" class="data row0 col7" >True</td>
#       <td id="T_ad4d9_row0_col8" class="data row0 col8" >M</td>
#       <td id="T_ad4d9_row0_col9" class="data row0 col9" >30932</td>
#       <td id="T_ad4d9_row0_col10" class="data row0 col10" ><a href="http://ratings.fide.com/card.phtml?event=4232984">4232984</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_ad4d9_row1_col0" class="data row1 col0" >ΡΗΓΑΤΟΣ ΠΑΝΑΓΙΩΤΗΣ</td>
#       <td id="T_ad4d9_row1_col1" class="data row1 col1" >1818</td>
#       <td id="T_ad4d9_row1_col2" class="data row1 col2" >1972</td>
#       <td id="T_ad4d9_row1_col3" class="data row1 col3" >1917</td>
#       <td id="T_ad4d9_row1_col4" class="data row1 col4" >1964</td>
#       <td id="T_ad4d9_row1_col5" class="data row1 col5" >30</td>
#       <td id="T_ad4d9_row1_col6" class="data row1 col6" >OK</td>
#       <td id="T_ad4d9_row1_col7" class="data row1 col7" >True</td>
#       <td id="T_ad4d9_row1_col8" class="data row1 col8" >M</td>
#       <td id="T_ad4d9_row1_col9" class="data row1 col9" >31687</td>
#       <td id="T_ad4d9_row1_col10" class="data row1 col10" ><a href="http://ratings.fide.com/card.phtml?event=4228146">4228146</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_ad4d9_row2_col0" class="data row2 col0" >ΛΑΣΠΑΣ ΠΑΝΑΓΙΩΤΗΣ</td>
#       <td id="T_ad4d9_row2_col1" class="data row2 col1" >1843</td>
#       <td id="T_ad4d9_row2_col2" class="data row2 col2" >1966</td>
#       <td id="T_ad4d9_row2_col3" class="data row2 col3" >1906</td>
#       <td id="T_ad4d9_row2_col4" class="data row2 col4" >1916</td>
#       <td id="T_ad4d9_row2_col5" class="data row2 col5" >25</td>
#       <td id="T_ad4d9_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_ad4d9_row2_col7" class="data row2 col7" >False</td>
#       <td id="T_ad4d9_row2_col8" class="data row2 col8" >M</td>
#       <td id="T_ad4d9_row2_col9" class="data row2 col9" >33571</td>
#       <td id="T_ad4d9_row2_col10" class="data row2 col10" ><a href="http://ratings.fide.com/card.phtml?event=4243102">4243102</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_ad4d9_row3_col0" class="data row3 col0" >ΚΑΛΟΦΩΝΟΣ ΠΑΝΑΓΙΩΤΗΣ</td>
#       <td id="T_ad4d9_row3_col1" class="data row3 col1" >1745</td>
#       <td id="T_ad4d9_row3_col2" class="data row3 col2" >1892</td>
#       <td id="T_ad4d9_row3_col3" class="data row3 col3" >1959</td>
#       <td id="T_ad4d9_row3_col4" class="data row3 col4" >1927</td>
#       <td id="T_ad4d9_row3_col5" class="data row3 col5" >25</td>
#       <td id="T_ad4d9_row3_col6" class="data row3 col6" >OK</td>
#       <td id="T_ad4d9_row3_col7" class="data row3 col7" >True</td>
#       <td id="T_ad4d9_row3_col8" class="data row3 col8" >M</td>
#       <td id="T_ad4d9_row3_col9" class="data row3 col9" >31682</td>
#       <td id="T_ad4d9_row3_col10" class="data row3 col10" ><a href="http://ratings.fide.com/card.phtml?event=4233824">4233824</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_ad4d9_row4_col0" class="data row4 col0" >ΛΙΑΠΗ ΖΕΝΕΜΠΙΣΗ ΕΙΡΗΝΗ</td>
#       <td id="T_ad4d9_row4_col1" class="data row4 col1" >1620</td>
#       <td id="T_ad4d9_row4_col2" class="data row4 col2" >1842</td>
#       <td id="T_ad4d9_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_ad4d9_row4_col4" class="data row4 col4" >1782</td>
#       <td id="T_ad4d9_row4_col5" class="data row4 col5" >26</td>
#       <td id="T_ad4d9_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_ad4d9_row4_col7" class="data row4 col7" >False</td>
#       <td id="T_ad4d9_row4_col8" class="data row4 col8" >F</td>
#       <td id="T_ad4d9_row4_col9" class="data row4 col9" >31828</td>
#       <td id="T_ad4d9_row4_col10" class="data row4 col10" ><a href="http://ratings.fide.com/card.phtml?event=4234120">4234120</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row5" class="row_heading level0 row5" >37</th>
#       <td id="T_ad4d9_row5_col0" class="data row5 col0" >ΜΑΡΓΑΡΙΤΗΣ ΙΩΑΝΝΗΣ</td>
#       <td id="T_ad4d9_row5_col1" class="data row5 col1" >1517</td>
#       <td id="T_ad4d9_row5_col2" class="data row5 col2" >1842</td>
#       <td id="T_ad4d9_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_ad4d9_row5_col4" class="data row5 col4" >1809</td>
#       <td id="T_ad4d9_row5_col5" class="data row5 col5" >26</td>
#       <td id="T_ad4d9_row5_col6" class="data row5 col6" >OK</td>
#       <td id="T_ad4d9_row5_col7" class="data row5 col7" >True</td>
#       <td id="T_ad4d9_row5_col8" class="data row5 col8" >M</td>
#       <td id="T_ad4d9_row5_col9" class="data row5 col9" >29091</td>
#       <td id="T_ad4d9_row5_col10" class="data row5 col10" ><a href="http://ratings.fide.com/card.phtml?event=4234219">4234219</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row6" class="row_heading level0 row6" >21</th>
#       <td id="T_ad4d9_row6_col0" class="data row6 col0" >ΚΟΥΤΣΙΔΗΣ ΑΧΙΛΛΕΥΣ</td>
#       <td id="T_ad4d9_row6_col1" class="data row6 col1" >1637</td>
#       <td id="T_ad4d9_row6_col2" class="data row6 col2" >1837</td>
#       <td id="T_ad4d9_row6_col3" class="data row6 col3" >1828</td>
#       <td id="T_ad4d9_row6_col4" class="data row6 col4" >1794</td>
#       <td id="T_ad4d9_row6_col5" class="data row6 col5" >25</td>
#       <td id="T_ad4d9_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_ad4d9_row6_col7" class="data row6 col7" >False</td>
#       <td id="T_ad4d9_row6_col8" class="data row6 col8" >M</td>
#       <td id="T_ad4d9_row6_col9" class="data row6 col9" >33312</td>
#       <td id="T_ad4d9_row6_col10" class="data row6 col10" ><a href="http://ratings.fide.com/card.phtml?event=4243080">4243080</a></td>
#     </tr>
#     <tr>
#       <th id="T_ad4d9_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_ad4d9_row7_col0" class="data row7 col0" >ΚΑΡΑΓΙΑΝΝΗΣ ΓΕΩΡΓΙΟΣ</td>
#       <td id="T_ad4d9_row7_col1" class="data row7 col1" >1577</td>
#       <td id="T_ad4d9_row7_col2" class="data row7 col2" >1804</td>
#       <td id="T_ad4d9_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_ad4d9_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_ad4d9_row7_col5" class="data row7 col5" >24</td>
#       <td id="T_ad4d9_row7_col6" class="data row7 col6" >0</td>
#       <

# %% [markdown]
# ### Search Player by name

# %%
import re
your_name = 'μαρκι'
your_name = your_name.upper()
# players_names_national = list(modified_players_list['National Name'])
row_index_match = [i for i in modified_players_list['National Name'].index  if re.search(your_name, modified_players_list['National Name'][i])]
table_toshow.iloc[row_index_match]
# Out:
#           National Name  National Elo   std  rapid  blitz  Age Eso Fee  \
# 35  ΜΑΡΚΙΔΟΥ ΧΡΙΣΤΙΑΝΝΑ          1554  1675   1866   1725   47       0
#
#     Fide Active Player Gender  National ID  \
# 35                True      F        37944
#
#                                     Fide ID hyperlink
# 35  <a href="http://ratings.fide.com/card.phtml?ev...

# %% [markdown]
# ## Statistics

# %%
# Groupin by 
modified_players_list.groupby(['Gender', 'Age']).apply(lambda df: df.head())
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14556\419794589.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   new_table.groupby(['Gender', 'Age']).apply(lambda df: df.head())
#                             National Name     Fide name  National Elo  std  \
# Gender Age
# F      8   438      ΦΟΥΝΤΟΥΛΑΚΗ ΣΤΑΥΡΟΥΛΑ             0             0    0
#        9   363      ΣΤΑΥΡΟΠΟΥΛΟΥ ΣΤΕΦΑΝΙΑ             0             0    0
#            405     ΤΣΙΑΚΟΠΟΥΛΟΥ ΑΛΕΞΑΝΔΡΑ             0             0    0
#        10  465               ΝΑΣΗ ΕΥΔΟΚΙΑ  Nasi Evdokia             0    0
#        11  357                ΜΠΑΘΑ ΑΘΗΝΑ  Batha Athina             0    0
# ...                                   ...           ...           ...  ...
# M      92  31          ΔΕΣΙΠΡΗΣ ΔΗΜΗΤΡΙΟΣ             0          1570    0
#        98  175  ΧΑΤΖΗΠΑΝΑΓΙΩΤΟΥ ΔΗΜΗΤΡΙΟΣ             0          1000    0
#        99  46      ΚΟΥΡΟΥΒΑΝΗΣ ΠΑΝΑΓΙΩΤΗΣ             0          1470    0
#            83            ΑΚΡΙΤΑΣ ΘΕΟΔΩΡΟΣ             0          1235    0
#        101 55        ΜΑΡΑΛΕΤΟΣ ΑΡΙΣΤΕΙΔΗΣ             0          1390    0
#
#                 rapid  blitz  Age Eso Fee  Fide Active Player Gender  ...  \
# Gender Age                                                            ...
# F      8   438      0      0    8      OK               False      F  ...
#        9   363      0      0    9       0               False      F  ...
#            405      0      0    9       0               False      F  ...
#        10  465      0      0   10      OK               False      F  ...
#        11  357      0      0   11      OK               False      F  ...
# ...               ...    ...  ...     ...                 ...    ...  ...
# M      92  31       0      0   92       0               False      M  ...
#        98  175      0      0   98       0               False      M  ...
#        99  46       0      0   99       0               False      M  ...
#            83       0      0   99       0               False      M  ...
#        101 55       0      0  101       0               False      M  ...
#
#                 National ID   Fide ID  Date of Birth National Title  \
# Gender Age
# F      8   438        59541         0        01/2016              0
#        9   363        59149         0        02/2015              0
#            405        59145         0        06/2015              0
#        10  465        60203  42186285        08/2014              0
#        11  357        59544  42182654        08/2013              0
# ...                     ...       ...            ...            ...
# M      92  31         10202         0        06/1932             ΒΚ
#        98  175         9846         0        01/1926             ΒΚ
#        99  46          9346         0        01/1925             ΒΚ
#            83          9845         0        01/1925             ΒΚ
#        101 55          2857         0        01/1923             ΔΚ
#
#                Games last 6 months  Outsider Federation National Rank All  \
# Gender Age
# F      8   438                   0         0          0                 0
#        9   363                   0         0          0                 0
#            405                   0         0          0                 0
#        10  465                   0         0          0                 0
#        11  357                   1         0          0                 0
# ...                            ...       ...        ...               ...
# M      92  31                    0         0          0                 0
#        98  175                   0         0          0                 0
#        99  46                    0         0          0                 0
#            83                    0         0          0                 0
#        101 55                    0         0          0                 0
#
#                 National Rank Active  Birthday parsed
# Gender Age
# F      8   438                     0       2016-01-01
#        9   363                     0       2015-02-01
#            405                     0       2015-06-01
#        10  465                     0       2014-08-01
#        11  357                     0       2013-08-01
# ...                              ...              ...
# M      92  31                      0       1932-06-01
#        98  175                     0       1926-01-01
#        99  46                      0       1925-01-01
#            83                      0       1925-01-01
#        101 55                      0       1923-01-01
#
# [342 rows x 21 columns]
